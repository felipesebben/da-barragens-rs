# %%
import pandas as pd
import os
import requests

# %%
dirname = os.getcwd()
data_in = f"{dirname}/data/raw/"
data_out = f"{dirname}/data/processed/"
output = f"{dirname}/data/output/"

def create_directory(path):
    """Creates directories if they don't exist"""
    if not os.path.exists(path):
        os.makedirs(path)

paths = [data_in, data_out, output]

list(map(create_directory, paths))
# Out:
# [None, None, None]

# %%
# URL obtained from the network inspection
url = 'https://www.snisb.gov.br/portal-snisb/api/file/download/4/dados-rsb-2022.xlsx'

# Send a GET request to the URL
response = requests.get(url)

# Save the XLSX content to a file
with open('dados-rsb-2022.xlsx', 'wb') as file:
    file.write(response.content)

df = pd.read_excel("dados-rsb-2022.xlsx", sheet_name=0)

# %%
# URL obtained from the network inspection
url = 'https://www.snisb.gov.br/portal-snisb/api/file/download/4/dados-rsb-2022.xlsx'

# Send a GET request to the URL
response = requests.get(url)

# Check if the response was successful
if response.status_code == 200:
    # Save the content to a file
    with open('dados-rsb-2022.xlsx', 'wb') as file:
        file.write(response.content)

    # Read the Excel file into a DataFrame
    df = pd.read_excel('dados-rsb-2022.xlsx')

    # Display or process your data
    print(df.head())  # Display the first few rows of the DataFrame
else:
    print("Failed to retrieve the file: Status code", response.status_code)
# Out:
#    Código SNISB       Nome da Barragem Nome Secundário Uso Principal  UF  \
# 0          1736  Barragem Esperança_IV             NaN   Aquicultura  AC
# 1          1743      Barragem Bambuí_I             NaN   Aquicultura  AC
# 2          1744     Barragem Bambuí_II             NaN   Aquicultura  AC
# 3          1691            Barragem JJ             NaN   Aquicultura  AC
# 4          1721          Barragem JJ_I             NaN   Aquicultura  AC
#
#   Município Categoria de Risco Dano Potencial Associado  \
# 0    BUJARI              Médio                    Baixo
# 1    BUJARI              Médio                    Baixo
# 2    BUJARI              Médio                    Baixo
# 3    BUJARI              Médio                    Baixo
# 4    BUJARI              Médio                    Baixo
#
#                 Nome do Empreendedor Tipo de Empreendedor  ...  \
# 0                      Kionori Kioki        Pessoa Física  ...
# 1  Antonio Luciano de Oliveira Filho        Pessoa Física  ...
# 2  Antonio Luciano de Oliveira Filho        Pessoa Física  ...
# 3               José Romildo Martins        Pessoa Física  ...
# 4               José Romildo Martins        Pessoa Física  ...
#
#   Tem informação de volume?    Faixa de volume  \
# 0                       Sim  Pequena até 1 hm³
# 1                       Sim  Pequena até 1 hm³
# 2                       Sim  Pequena até 1 hm³
# 3                       Sim  Pequena até 1 hm³
# 4                       Sim  Pequena até 1 hm³
#
#   Tem informação de altura e volume? classificada quanto ao CRI?  \
# 0                                Sim                         Sim
# 1                                Sim                         Sim
# 2                                Sim                         Sim
# 3                                Sim                         Sim
# 4                                Sim                         Sim
#
#   classificada quanto ao DPA? Houve alguma inspeção no período deste RSB?  \
# 0                         Sim                                         Não
# 1                         Sim                                         Não
# 2                         Sim                                         Não
# 3                         Sim                                         Não
# 4                         Sim                                         Não
#
#   Houve alguma fiscalização no período deste RSB?  \
# 0                                             Não
# 1                                             Não
# 2                                             Não
# 3                                             Não
# 4                                             Não
#
#   Está entre as que mais preocupam o fiscalizador?  N  sequência
# 0                                              Não  1        151
# 1                                              Não  1        152
# 2                                              Não  1        160
# 3                                              Não  1        165
# 4                                              Não  1        173
#
# [5 rows x 53 columns]

# %%
df.head()
# Out:
#    Código SNISB       Nome da Barragem Nome Secundário Uso Principal  UF  \
# 0          1736  Barragem Esperança_IV             NaN   Aquicultura  AC
# 1          1743      Barragem Bambuí_I             NaN   Aquicultura  AC
# 2          1744     Barragem Bambuí_II             NaN   Aquicultura  AC
# 3          1691            Barragem JJ             NaN   Aquicultura  AC
# 4          1721          Barragem JJ_I             NaN   Aquicultura  AC
#
#   Município Categoria de Risco Dano Potencial Associado  \
# 0    BUJARI              Médio                    Baixo
# 1    BUJARI              Médio                    Baixo
# 2    BUJARI              Médio                    Baixo
# 3    BUJARI              Médio                    Baixo
# 4    BUJARI              Médio                    Baixo
#
#                 Nome do Empreendedor Tipo de Empreendedor  ...  \
# 0                      Kionori Kioki        Pessoa Física  ...
# 1  Antonio Luciano de Oliveira Filho        Pessoa Física  ...
# 2  Antonio Luciano de Oliveira Filho        Pessoa Física  ...
# 3               José Romildo Martins        Pessoa Física  ...
# 4               José Romildo Martins        Pessoa Física  ...
#
#   Tem informação de volume?    Faixa de volume  \
# 0                       Sim  Pequena até 1 hm³
# 1                       Sim  Pequena até 1 hm³
# 2                       Sim  Pequena até 1 hm³
# 3                       Sim  Pequena até 1 hm³
# 4                       Sim  Pequena até 1 hm³
#
#   Tem informação de altura e volume? classificada quanto ao CRI?  \
# 0                                Sim                         Sim
# 1                                Sim                         Sim
# 2                                Sim                         Sim
# 3                                Sim                         Sim
# 4                                Sim                         Sim
#
#   classificada quanto ao DPA? Houve alguma inspeção no período deste RSB?  \
# 0                         Sim                                         Não
# 1                         Sim                                         Não
# 2                         Sim                                         Não
# 3                         Sim                                         Não
# 4                         Sim                                         Não
#
#   Houve alguma fiscalização no período deste RSB?  \
# 0                                             Não
# 1                                             Não
# 2                                             Não
# 3                                             Não
# 4                                             Não
#
#   Está entre as que mais preocupam o fiscalizador?  N  sequência
# 0                                              Não  1        151
# 1                                              Não  1        152
# 2                                              Não  1        160
# 3                                              Não  1        165
# 4                                              Não  1        173
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Filter the Data ##
# We can reduce our dataset straight away - we only need dams registered in Rio Grande do Sul (UF as `RS`).

# %%
df_cut = df.loc[df["UF"] == "RS", :]

# %% [markdown]
# ## Understand the structure ##

# %%
print(f"Number of rows: {df_cut.shape[0]}\nNumber of columns: {df_cut.shape[1]}")
# Out:
# Number of rows: 10106
# Number of columns: 53

# %%
# Get overview of each column
df_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10106 entries, 2415 to 23526
# Data columns (total 53 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Código SNISB                                      10106 non-null  int64
#  1   Nome da Barragem                                  10106 non-null  object
#  2   Nome Secundário                                   5 non-null      object
#  3   Uso Principal                                     10106 non-null  object
#  4   UF                                                10106 non-null  object
#  5   Município                                         10106 non-null  object
#  6   Categoria de Risco                                10106 non-null  object
#  7   Dano Potencial Associado                          10106 non-null  object
#  8   Nome do Empreendedor                              10106 non-null  object
#  9   Tipo de Empreendedor                              10106 non-null  object
#  10  Órgão Fiscalizador                                10106 non-null  object
#  11  Código Barragem no Fiscalizador                   2647 non-null   object
#  12  Regulada pela PNSB                                10106 non-null  object
#  13  Número da Autorização                             2926 non-null   object
#  14  Possui PAE                                        224 non-null    object
#  15  Possui Plano de Segurança                         10106 non-null  object
#  16  Possui Revisão Periódica                          10106 non-null  object
#  17  Data da Última Fiscalização                       17 non-null     datetime64[ns]
#  18  Barragem Autuada                                  10106 non-null  object
#  19  Altura Fundação (m)                               1564 non-null   float64
#  20  Altura Terreno (m)                                1325 non-null   float64
#  21  Capacidade (hm³)                                  9108 non-null   float64
#  22  Comprimento Coroamento (m)                        255 non-null    float64
#  23  Tipo de Material                                  10106 non-null  object
#  24  Uso Complementar                                  39 non-null     object
#  25  Classe de Resíduo                                 0 non-null      object
#  26  Código Curso Dágua Barrado                        9855 non-null   float64
#  27  Nome_Curso_dágua                                  10106 non-null  object
#  28  Região Hidrográfica                               10106 non-null  object
#  29  Unidade de Gestão                                 10106 non-null  object
#  30  Data da Última Inspeção                           5 non-null      datetime64[ns]
#  31  Tipo da Última Inspeção                           5 non-null      object
#  32  Nível de Perigo Global                            1 non-null      object
#  33  Possui Eclusa                                     113 non-null    object
#  34  Fase da Vida                                      131 non-null    object
#  35  Latitude                                          10106 non-null  float64
#  36  Longitude                                         10106 non-null  float64
#  37  Completude dos dados                              10106 non-null  object
#  38  Barragem Outorgada?                               10106 non-null  object
#  39  Empreendedor Identificado?                        10106 non-null  object
#  40  Tem informação de altura?                         10106 non-null  object
#  41  Maior altura (fundação ou terreno)                10106 non-null  object
#  42  Faixa de altura                                   10106 non-null  object
#  43  Tem informação de volume?                         10106 non-null  object
#  44  Faixa de volume                                   10106 non-null  object
#  45  Tem informação de altura e volume?                10106 non-null  object
#  46  classificada quanto ao CRI?                       10106 non-null  object
#  47  classificada quanto ao DPA?                       10106 non-null  object
#  48  Houve alguma inspeção no período deste RSB?       10106 non-null  object
#  49  Houve alguma fiscalização no período deste RSB?   10106 non-null  object
#  50  Está entre as que mais preocupam o fiscalizador?  10106 non-null  object
#  51  N                                                 10106 non-null  int64
#  52  sequência                                         10106 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(3), object(41)
# memory usage: 4.2+ MB

# %%
missing_values = df_cut.isnull().sum()
perc_missing = round((missing_values / df_cut.shape[0])*100,1)
duplicates = df_cut.duplicated().sum()
dtype = df_cut.dtypes
data = {
    "data_type": dtype,
    "missing_values": missing_values, 
    "percentage_missing": perc_missing,
    "n_duplicates": duplicates
    }
df2 = pd.DataFrame(data)
df2
# Out:
#                                                        data_type  \
# Código SNISB                                               int64
# Nome da Barragem                                          object
# Nome Secundário                                           object
# Uso Principal                                             object
# UF                                                        object
# Município                                                 object
# Categoria de Risco                                        object
# Dano Potencial Associado                                  object
# Nome do Empreendedor                                      object
# Tipo de Empreendedor                                      object
# Órgão Fiscalizador                                        object
# Código Barragem no Fiscalizador                           object
# Regulada pela PNSB                                        object
# Número da Autorização                                     object
# Possui PAE                                                object
# Possui Plano de Segurança                                 object
# Possui Revisão Periódica                                  object
# Data da Última Fiscalização                       datetime64[ns]
# Barragem Autuada                                          object
# Altura Fundação (m)                                      float64
# Altura Terreno (m)                                       float64
# Capacidade (hm³)                                         float64
# Comprimento Coroamento (m)                               float64
# Tipo de Material                                          object
# Uso Complementar                                          object
# Classe de Resíduo                                         object
# Código Curso Dágua Barrado                               float64
# Nome_Curso_dágua                                          object
# Região Hidrográfica                                       object
# Unidade de Gestão                                         object
# Data da Última Inspeção                           datetime64[ns]
# Tipo da Última Inspeção                                   object
# Nível de Perigo Global                                    object
# Possui Eclusa                                             object
# Fase da Vida                                              object
# Latitude                                                 float64
# Longitude                                                float64
# Completude dos dados                                      object
# Barragem Outorgada?                                       object
# Empreendedor Identificado?                                object
# Tem informação de altura?                                 object
# Maior altura (fundação ou terreno)                        object
# Faixa de altura                                           object
# Tem informação de volume?                                 object
# Faixa de volume                                           object
# Tem informação de altura e volume?                        object
# classificada quanto ao CRI?                               object
# classificada quanto ao DPA?                               object
# Houve alguma inspeção no período deste RSB?               object
# Houve alguma fiscalização no período deste RSB?           object
# Está entre as que mais preocupam o fiscalizador?          object
# N                                                          int64
# sequência                                                  int64
#
#                                                   missing_values  \
# Código SNISB                                                   0
# Nome da Barragem                                               0
# Nome Secundário                                            10101
# Uso Principal                                                  0
# UF                                                             0
# Município                                                      0
# Categoria de Risco                                             0
# Dano Potencial Associado                                       0
# Nome do Empreendedor                                           0
# Tipo de Empreendedor                                           0
# Órgão Fiscalizador                                             0
# Código Barragem no Fiscalizador                             7459
# Regulada pela PNSB                                             0
# Número da Autorização                                       7180
# Possui PAE                                                  9882
# Possui Plano de Segurança                                      0
# Possui Revisão Periódica                                       0
# Data da Última Fiscalização                                10089
# Barragem Autuada                                               0
# Altura Fundação (m)                                         8542
# Altura Terreno (m)                                          8781
# Capacidade (hm³)                                             998
# Comprimento Coroamento (m)                                  9851
# Tipo de Material                                               0
# Uso Complementar                                           10067
# Classe de Resíduo                                          10106
# Código Curso Dágua Barrado                                   251
# Nome_Curso_dágua                                               0
# Região Hidrográfica                                            0
# Unidade de Gestão                                              0
# Data da Última Inspeção                                    10101
# Tipo da Última Inspeção                                    10101
# Nível de Perigo Global                                     10105
# Possui Eclusa                                               9993
# Fase da Vida                                                9975
# Latitude                                                       0
# Longitude                                                      0
# Completude dos dados                                           0
# Barragem Outorgada?                                            0
# Empreendedor Identificado?                                     0
# Tem informação de altura?                                      0
# Maior altura (fundação ou terreno)                             0
# Faixa de altura                                                0
# Tem informação de volume?                                      0
# Faixa de volume                                                0
# Tem informação de altura e volume?                             0
# classificada quanto ao CRI?                                    0
# classificada quanto ao DPA?                                    0
# Houve alguma inspeção no período deste RSB?                    0
# Houve alguma fiscalização no período deste RSB?                0
# Está entre as que mais preocupam o fiscalizador?               0
# N                                                              0
# sequência                                                      0
#
#                                                   percentage_missing  \
# Código SNISB                                                     0.0
# Nome da Barragem                                                 0.0
# Nome Secundário                                                100.0
# Uso Principal                                                    0.0
# UF                                                               0.0
# Município                                                        0.0
# Categoria de Risco                                               0.0
# Dano Potencial Associado                                         0.0
# Nome do Empreendedor                                             0.0
# Tipo de Empreendedor                                             0.0
# Órgão Fiscalizador                                               0.0
# Código Barragem no Fiscalizador                                 73.8
# Regulada pela PNSB                                               0.0
# Número da Autorização                                           71.0
# Possui PAE                                                      97.8
# Possui Plano de Segurança                                        0.0
# Possui Revisão Periódica                                         0.0
# Data da Última Fiscalização                                     99.8
# Barragem Autuada                                                 0.0
# Altura Fundação (m)                                             84.5
# Altura Terreno (m)                                              86.9
# Capacidade (hm³)                                                 9.9
# Comprimento Coroamento (m)                                      97.5
# Tipo de Material                                                 0.0
# Uso Complementar                                                99.6
# Classe de Resíduo                                              100.0
# Código Curso Dágua Barrado                                       2.5
# Nome_Curso_dágua                                                 0.0
# Região Hidrográfica                                              0.0
# Unidade de Gestão                                                0.0
# Data da Última Inspeção                                        100.0
# Tipo da Última Inspeção                                        100.0
# Nível de Perigo Global                                         100.0
# Possui Eclusa                                                   98.9
# Fase da Vida                                                    98.7
# Latitude                                                         0.0
# Longitude                                                        0.0
# Completude dos dados                                             0.0
# Barragem Outorgada?                                              0.0
# Empreendedor Identificado?                                       0.0
# Tem informação de altura?                                        0.0
# Maior altura (fundação ou terreno)                               0.0
# Faixa de altura                                                  0.0
# Tem informação de volume?                                        0.0
# Faixa de volume                                                  0.0
# Tem informação de altura e volume?                               0.0
# classificada quanto ao CRI?                                      0.0
# classificada quanto ao DPA?                                      0.0
# Houve alguma inspeção no período deste RSB?                      0.0
# Houve alguma fiscalização no período deste RSB?                  0.0
# Está entre as que mais preocupam o fiscalizador?                 0.0
# N                                                                0.0
# sequência                                                        0.0
#
#                                                   n_duplicates
# Código SNISB                                                 0
# Nome da Barragem                                             0
# Nome Secundário                                              0
# Uso Principal                                                0
# UF                                                           0
# Município                                                    0
# Categoria de Risco                                           0
# Dano Potencial Associado                                     0
# Nome do Empreendedor                                         0
# Tipo de Empreendedor                                         0
# Órgão Fiscalizador                                           0
# Código Barragem no Fiscalizador                              0
# Regulada pela PNSB                                           0
# Número da Autorização                                        0
# Possui PAE                                                   0
# Possui Plano de Segurança                                    0
# Possui Revisão Periódica                                     0
# Data da Última Fiscalização                                  0
# Barragem Autuada                                             0
# Altura Fundação (m)                                          0
# Altura Terreno (m)                                           0
# Capacidade (hm³)                                             0
# Comprimento Coroamento (m)                                   0
# Tipo de Material                                             0
# Uso Complementar                                             0
# Classe de Resíduo                                            0
# Código Curso Dágua Barrado                                   0
# Nome_Curso_dágua                                             0
# Região Hidrográfica                                          0
# Unidade de Gestão                                            0
# Data da Última Inspeção                                      0
# Tipo da Última Inspeção                                      0
# Nível de Perigo Global                                       0
# Possui Eclusa                                                0
# Fase da Vida                                                 0
# Latitude                                                     0
# Longitude                                                    0
# Completude dos dados                                         0
# Barragem Outorgada?                                          0
# Empreendedor Identificado?                                   0
# Tem informação de altura?                                    0
# Maior altura (fundação ou terreno)                           0
# Faixa de altura                                              0
# Tem informação de volume?                                    0
# Faixa de volume                                              0
# Tem informação de altura e volume?                           0
# classificada quanto ao CRI?                                  0
# classificada quanto ao DPA?                                  0
# Houve alguma inspeção no período deste RSB?                  0
# Houve alguma fiscalização no período deste RSB?              0
# Está entre as que mais preocupam o fiscalizador?             0
# N                                                            0
# sequência                                                    0

# %% [markdown]
# ## Evaluate Columns ##
# We must focus on columns that directly relate to:
# - Dam identification and location
# - Risk and potential damage
# - Inspection and regulation details
# - Structural characteristics

# %%
df_cut.columns
# Out:
# Index(['Código SNISB', 'Nome da Barragem', 'Nome Secundário', 'Uso Principal',
#        'UF', 'Município', 'Categoria de Risco', 'Dano Potencial Associado',
#        'Nome do Empreendedor', 'Tipo de Empreendedor', 'Órgão Fiscalizador',
#        'Código Barragem no Fiscalizador', 'Regulada pela PNSB',
#        'Número da Autorização', 'Possui PAE', 'Possui Plano de Segurança',
#        'Possui Revisão Periódica', 'Data da Última Fiscalização',
#        'Barragem Autuada', 'Altura Fundação (m)', 'Altura Terreno (m)',
#        'Capacidade (hm³)', 'Comprimento Coroamento (m)', 'Tipo de Material',
#        'Uso Complementar', 'Classe de Resíduo', 'Código Curso Dágua Barrado',
#        'Nome_Curso_dágua ', 'Região Hidrográfica', 'Unidade de Gestão',
#        'Data da Última Inspeção', 'Tipo da Última Inspeção',
#        'Nível de Perigo Global', 'Possui Eclusa', 'Fase da Vida', 'Latitude',
#        'Longitude', 'Completude dos dados', 'Barragem Outorgada?',
#        'Empreendedor Identificado?', 'Tem informação de altura?',
#        'Maior altura (fundação ou terreno)', 'Faixa de altura',
#        'Tem informação de volume?', 'Faixa de volume',
#        'Tem informação de altura e volume?', 'classificada quanto ao CRI?',
#        'classificada quanto ao DPA?',
#        'Houve alguma inspeção no período deste RSB?',
#        'Houve alguma fiscalização no período deste RSB?',
#        'Está entre as que mais preocupam o fiscalizador?', 'N', 'sequência'],
#       dtype='object')

# %%
df2.loc[df2["percentage_missing"] > 90]
# Out:
#                                   data_type  missing_values  \
# Nome Secundário                      object           10101
# Possui PAE                           object            9882
# Data da Última Fiscalização  datetime64[ns]           10089
# Comprimento Coroamento (m)          float64            9851
# Uso Complementar                     object           10067
# Classe de Resíduo                    object           10106
# Data da Última Inspeção      datetime64[ns]           10101
# Tipo da Última Inspeção              object           10101
# Nível de Perigo Global               object           10105
# Possui Eclusa                        object            9993
# Fase da Vida                         object            9975
#
#                              percentage_missing  n_duplicates
# Nome Secundário                           100.0             0
# Possui PAE                                 97.8             0
# Data da Última Fiscalização                99.8             0
# Comprimento Coroamento (m)                 97.5             0
# Uso Complementar                           99.6             0
# Classe de Resíduo                         100.0             0
# Data da Última Inspeção                   100.0             0
# Tipo da Última Inspeção                   100.0             0
# Nível de Perigo Global                    100.0             0
# Possui Eclusa                              98.9             0
# Fase da Vida                               98.7             0

# %%
df_cut["Está entre as que mais preocupam o fiscalizador?"].value_counts()
# Out:
# Está entre as que mais preocupam o fiscalizador?
# Não    10095
# sim       11
# Name: count, dtype: int64

# %%
df_cut['Órgão Fiscalizador'].unique()
# Out:
# array(['RS - Secretaria de Meio Ambiente e Infraestrutura - SEMA',
#        'Agência Nacional de Águas e Saneamento Básico - ANA',
#        'Agência Nacional de Energia Elétrica - ANEEL',
#        'Agência Nacional de Mineração - ANM'], dtype=object)

# %%
columns_to_keep = [
    # Identification
    'Código SNISB', 'Nome da Barragem',
    # Location
    'UF', 'Município', 'Latitude', 'Longitude',
    # Risk + Regulation
    'Categoria de Risco', 'Dano Potencial Associado',
    'Regulada pela PNSB', 'Possui Plano de Segurança',
    'Possui Revisão Periódica', 'Completude dos dados',
    # Structural Info   
    'Altura Fundação (m)', 'Capacidade (hm³)', 
    'Nome_Curso_dágua ', 
    'Faixa de altura','Faixa de volume',]

# %%
df_cut_refined = df_cut[columns_to_keep]

df_cut_refined.head()
# Out:
#       Código SNISB                                   Nome da Barragem  UF  \
# 2415          5324                            Elias Scholsser Doviggi  RS
# 2465          5420        COOPERATIVA AGRICOLA MISTA SÃO MARCOS LTDA.  RS
# 2468          6421                   Instituto Rio Grandense do Arroz  RS
# 2682          6514  AUD - Associação dos Usuários do Perímetro de ...  RS
# 7729         17114  Associação dos Moradores do Assentamento Filho...  RS
#
#              Município  Latitude  Longitude Categoria de Risco  \
# 2415   BARRA DO QUARAÍ -30.21858  -57.48136   Não Classificado
# 2465        URUGUAIANA -29.54631  -56.82289   Não Classificado
# 2468  CACHOEIRA DO SUL -30.22500  -52.93972   Não Classificado
# 2682           CAMAQUÃ -30.82069  -51.84369              Médio
# 7729            VIAMÃO -30.07369  -50.86181   Não Classificado
#
#      Dano Potencial Associado Regulada pela PNSB Possui Plano de Segurança  \
# 2415         Não Classificado                Sim                       Não
# 2465         Não Classificado                Sim                       Não
# 2468         Não Classificado                Sim                       Não
# 2682                     Alto                Sim                       Não
# 7729         Não Classificado                Sim                       Não
#
#      Possui Revisão Periódica Completude dos dados  Altura Fundação (m)  \
# 2415                      Não                média                 8.19
# 2465                      Não                média                 7.00
# 2468                      Não                média                13.50
# 2682                      Não                  boa                26.00
# 7729                      Não                média                14.62
#
#       Capacidade (hm³)    Nome_Curso_dágua    Faixa de altura  \
# 2415             3.192  Arroio Quaraí Chico  7,5 m < h < 15 m
# 2465            60.965             SEM NOME         h < 7,5 m
# 2468            34.779   Arroio Capanezinho  7,5 m < h < 15 m
# 2682           170.000          Arroio Duro   15 m < h < 30 m
# 7729            12.973             SEM NOME  7,5 m < h < 15 m
#
#               Faixa de volume
# 2415  Pequena entre 3 e 5 hm³
# 2465                    Média
# 2468                    Média
# 2682                   Grande
# 7729                    Média

# %%
df_cut_refined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10106 entries, 2415 to 23526
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código SNISB               10106 non-null  int64
#  1   Nome da Barragem           10106 non-null  object
#  2   UF                         10106 non-null  object
#  3   Município                  10106 non-null  object
#  4   Latitude                   10106 non-null  float64
#  5   Longitude                  10106 non-null  float64
#  6   Categoria de Risco         10106 non-null  object
#  7   Dano Potencial Associado   10106 non-null  object
#  8   Regulada pela PNSB         10106 non-null  object
#  9   Possui Plano de Segurança  10106 non-null  object
#  10  Possui Revisão Periódica   10106 non-null  object
#  11  Completude dos dados       10106 non-null  object
#  12  Altura Fundação (m)        1564 non-null   float64
#  13  Capacidade (hm³)           9108 non-null   float64
#  14  Nome_Curso_dágua           10106 non-null  object
#  15  Faixa de altura            10106 non-null  object
#  16  Faixa de volume            10106 non-null  object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Check Data Types, Convert if Necessary ##
# We don't need to change any dtype for now. All data types seem to match our actual data.
#
# ## Standardize Categorical Data ##
# Let's identify our **key categorical columns**:
# Identify Key Categorical Columns: Determine which columns are suitable for standardization, such as:
# - `UF`
# - `Município`
# - `Categoria de Risco`
# - `Dano Potencial Associado`
# - `Regulada pela PNSB`
# - `Possui Plano de Segurança`
# - `Possui Revisão Periódica`
# - `Completude dos dados`
# - `Faixa de altura`
# - `Faixa de volume`

# %% [markdown]
# ### 1. `UF`

# %%
df_cut_refined["UF"].unique()
# Out:
# array(['RS'], dtype=object)

# %% [markdown]
# No need for any transformation - `RS` is the only category.
#
# ### 2. `Município`

# %%
df_cut_refined["Município"].unique()
# Out:
# array(['BARRA DO QUARAÍ', 'URUGUAIANA', 'CACHOEIRA DO SUL', 'CAMAQUÃ',
#        'VIAMÃO', 'SÃO GABRIEL', 'PORTO ALEGRE', 'CANELA', 'BAGÉ',
#        'RIO GRANDE', 'TAPES', 'ROSÁRIO DO SUL', 'ARROIO GRANDE',
#        'DOM PEDRITO', 'CRISTAL', 'SÃO LOURENÇO DO SUL', 'JAGUARÃO',
#        'CANDIOTA', 'ACEGUÁ', 'ENCRUZILHADA DO SUL', 'ITAQUI',
#        'SÃO VICENTE DO SUL', 'SÃO PEDRO DO SUL', 'TURUÇU', 'SANTO ÂNGELO',
#        'JÓIA', 'ENTRE-IJUÍS', 'TUPANCIRETÃ', 'IJUÍ', 'CRUZ ALTA',
#        'NOVA RAMADA', 'CAMPO NOVO', 'BOM JESUS', 'PINHAL DA SERRA',
#        'SÃO JOSÉ DOS AUSENTES', 'QUARAÍ', "SANT'ANA DO LIVRAMENTO",
#        'PALMEIRA DAS MISSÕES', 'DOUTOR MAURÍCIO CARDOSO',
#        'BENTO GONÇALVES', 'PASSO DO SOBRADO', 'SÃO FRANCISCO DE PAULA',
#        'VENÂNCIO AIRES', 'IPÊ', 'RIO PARDO', 'MINAS DO LEÃO',
#        'CAMPESTRE DA SERRA', 'NOVA PRATA', 'JAQUIRANA', 'SANTA TEREZA',
#        'AGUDO', 'SÃO JERÔNIMO', 'SANTIAGO', 'SÃO LUIZ GONZAGA',
#        'CAMPINA DAS MISSÕES', 'ROLADOR', 'UNISTALDA',
#        'SÃO FRANCISCO DE ASSIS', 'SÃO PAULO DAS MISSÕES',
#        'ROQUE GONZALES', 'BOSSOROCA', 'CACEQUI', 'ALEGRETE',
#        'LAVRAS DO SUL', 'NOVA ESPERANÇA DO SUL', 'CÂNDIDO GODÓI', 'MATA',
#        'JAGUARI', 'MATO QUEIMADO', 'MAÇAMBARÁ', 'DILERMANDO DE AGUIAR',
#        'SANTA MARGARIDA DO SUL', 'SÃO BORJA', 'PORTO LUCENA', 'SÃO SEPÉ',
#        'SANTA MARIA', 'JÚLIO DE CASTILHOS', 'SANTO CRISTO', 'ITACURUBI',
#        'SANTA BÁRBARA DO SUL', 'CAÇAPAVA DO SUL', 'IBIRUBÁ', 'BARRACÃO',
#        'CANDELÁRIA', 'CAPÃO DO LEÃO', 'PELOTAS', 'SALVADOR DAS MISSÕES',
#        'CAMBARÁ DO SUL', 'ERVAL SECO', 'TRÊS DE MAIO', 'TIO HUGO',
#        'FORMIGUEIRO', 'RIO DOS ÍNDIOS', 'ANDRÉ DA ROCHA', 'BUTIÁ',
#        'BARRA DO RIBEIRO', 'PORTÃO', 'CACHOEIRINHA', 'SAPIRANGA',
#        'ARARICÁ', 'MOSTARDAS', 'GRAVATAÍ', 'GLORINHA', 'TAQUARA',
#        'SANTO ANTÔNIO DA PATRULHA', 'PIRAPÓ', 'SANTO ANTÔNIO DAS MISSÕES',
#        'PORTO XAVIER', 'DEZESSEIS DE NOVEMBRO', 'GARRUCHOS',
#        'MANOEL VIANA', 'SÃO NICOLAU', 'PANTANO GRANDE', 'NOVO CABRAIS',
#        'IRAÍ', 'RODEIO BONITO', 'ESTRELA VELHA', 'FORTALEZA DOS VALOS',
#        'IBARAMA', 'PINHEIRINHO DO VALE', 'CONDOR', 'VISTA ALEGRE',
#        'PINHEIRO MACHADO', 'FREDERICO WESTPHALEN', 'RESTINGA SECA',
#        'PARAÍSO DO SUL', 'ALPESTRE', 'CERRO GRANDE', 'PEJUÇARA',
#        'SÃO JOÃO DO POLÊSINE', 'DONA FRANCISCA', 'HERVAL', 'SEBERI',
#        'PALMITINHO', 'CAIÇARA', 'DOIS IRMÃOS DAS MISSÕES',
#        'SANTA VITÓRIA DO PALMAR', 'BOA VISTA DAS MISSÕES', 'PIRATINI',
#        'SANTO AUGUSTO', 'SAGRADA FAMÍLIA', 'JABOTICABA', 'NOVO XINGU',
#        'NOVO BARREIRO', 'PANAMBI', 'PINHAL', 'CHAPADA', 'HULHA NEGRA',
#        'PINHAL GRANDE', 'BOA VISTA DO CADEADO', 'SALTO DO JACUÍ',
#        'NOVA PALMA', 'TENENTE PORTELA', 'LAJEADO DO BUGRE',
#        'CORONEL BICACO', 'REDENTORA', 'SENADOR SALGADO FILHO',
#        'CAPÃO DO CIPÓ', 'TIRADENTES DO SUL', 'BARRA FUNDA',
#        'LIBERATO SALZANO', 'CAMPOS BORGES', 'SETE DE SETEMBRO',
#        'SÃO MIGUEL DAS MISSÕES', 'TUCUNDUVA', 'NOVA CANDELÁRIA',
#        'SELBACH', 'PEDRO OSÓRIO', 'CONSTANTINA', 'SANTA ROSA',
#        'CERRO BRANCO', 'GIRUÁ', 'CAIBATÉ', 'ALEGRIA', 'AUGUSTO PESTANA',
#        'GUARANI DAS MISSÕES', 'PORTO MAUÁ', 'UBIRETAMA', 'CATUÍPE',
#        'TUPARENDI', 'INDEPENDÊNCIA', 'HORIZONTINA', 'CHIAPETTA',
#        'VILA NOVA DO SUL', 'PEDRAS ALTAS', 'JARI', 'PASSA SETE',
#        'ENGENHO VELHO', 'NOVO MACHADO', 'BOA VISTA DO BURICÁ',
#        'CARAZINHO', 'RONDINHA', 'JACUIZINHO', 'NONOAI', 'CERRITO',
#        'CANGUÇU', 'TRINDADE DO SUL', 'VITÓRIA DAS MISSÕES', 'SANANDUVA',
#        'TEUTÔNIA', 'TRIUNFO', 'ENTRE RIOS DO SUL', 'LAGOÃO',
#        'BARÃO DE COTEGIPE', 'PROGRESSO', 'SÃO JOÃO DA URTIGA',
#        'MAXIMILIANO DE ALMEIDA', 'GUAPORÉ', 'ARROIO DOS RATOS',
#        'ELDORADO DO SUL', 'SERTÃO', 'GARIBALDI', 'LAGOA VERMELHA',
#        'PONTÃO', 'SANTO ANTÔNIO DO PLANALTO', 'MARAU', 'ERECHIM',
#        'MACHADINHO', 'DAVID CANABARRO', 'VERANÓPOLIS', 'MATO CASTELHANO',
#        'ARATIBA', 'GENERAL CÂMARA', 'NOVA BASSANO', 'ANTÔNIO PRADO',
#        'MORMAÇO', 'TRÊS ARROIOS', 'MARIANO MORO', 'BARÃO', 'PASSO FUNDO',
#        'MORRO REDONDO', 'SÃO VALENTIM', 'CAMPINAS DO SUL',
#        'CARLOS BARBOSA', 'VALE VERDE', 'CERRO GRANDE DO SUL',
#        'VISTA ALEGRE DO PRATA', 'ERVAL GRANDE', 'ÁUREA', 'IBIRAIARAS',
#        'SERTÃO SANTANA', 'PARECI NOVO', 'SANTA CLARA DO SUL', 'GENTIL',
#        'SENTINELA DO SUL', 'BOQUEIRÃO DO LEÃO', 'SANTO ANTÔNIO DO PALMA',
#        'CHUVISCA', 'GUAÍBA', 'BOM PRINCÍPIO', 'ÁGUA SANTA',
#        'QUATRO IRMÃOS', 'CHARQUEADAS', 'PROTÁSIO ALVES',
#        'AMARAL FERRADOR', 'BARRA DO RIO AZUL', 'SOLEDADE', 'IBIRAPUITÃ',
#        'TAPEJARA', 'SANTA CECÍLIA DO SUL', 'CIRÍACO', 'SÃO JOSÉ DO OURO',
#        'ESPUMOSO', 'LAGOA DOS TRÊS CANTOS', 'SERAFINA CORRÊA', 'VACARIA',
#        'TAVARES', 'CAXIAS DO SUL', 'TORRES', 'NOVA HARTZ',
#        'NOVA ROMA DO SUL', 'SÃO SEBASTIÃO DO CAÍ', 'CAPELA DE SANTANA',
#        'TRÊS COROAS', 'NOVA PÁDUA', 'FLORES DA CUNHA', 'ROLANTE',
#        'SÃO JOSÉ DO HORTÊNCIO', 'MUITOS CAPÕES', 'NOVA PETRÓPOLIS',
#        'PALMARES DO SUL', 'ESTÂNCIA VELHA', 'RIOZINHO', 'CARAÁ',
#        'DOIS IRMÃOS', 'ALVORADA', 'OSÓRIO', 'TERRA DE AREIA', 'ITATI',
#        'XANGRI-LÁ', 'GETÚLIO VARGAS', 'PLANALTO', 'EREBANGO', 'CASCA',
#        'EUGÊNIO DE CASTRO', 'PAULO BENTO', 'FONTOURA XAVIER', 'ALECRIM',
#        'CERRO LARGO', 'DOIS LAJEADOS', 'MONTENEGRO', 'VICTOR GRAEFF',
#        'BRAGA', 'TAPERA', 'SANTANA DA BOA VISTA', 'COTIPORÃ',
#        'FARROUPILHA', 'CAMPO BOM', 'TAQUARUÇU DO SUL',
#        'FAXINAL DO SOTURNO', 'NOVO TIRADENTES', 'SILVEIRA MARTINS',
#        'SÃO PEDRO DAS MISSÕES', 'BOZANO', 'ITAARA', 'VISTA GAÚCHA',
#        'SOBRADINHO', 'SÃO VALÉRIO DO SUL', 'TRÊS PASSOS',
#        'GRAMADO DOS LOUREIROS', 'SARANDI', 'SÃO JOSÉ DO INHACORÁ',
#        'COQUEIROS DO SUL', 'COXILHA', 'SÃO MARTINHO DA SERRA',
#        'FAZENDA VILANOVA', 'DOM FELICIANO', 'PAIM FILHO', 'IBIAÇÁ',
#        'MULITERNO', 'CRUZALTENSE', 'SÃO VALENTIM DO SUL',
#        'MARIANA PIMENTEL', 'CAPÃO BONITO DO SUL', 'GAURAMA', 'NOVA ARAÇÁ',
#        'SEVERIANO DE ALMEIDA', 'ERNESTINA', 'VILA LÂNGARO',
#        'MONTE BELO DO SUL', 'FAGUNDES VARELA', 'CRUZEIRO DO SUL',
#        'UNIÃO DA SERRA', 'ARAMBARÉ', 'TRÊS PALMEIRAS', 'TAQUARI',
#        'CAPÃO DA CANOA', 'PRESIDENTE LUCENA', 'PICADA CAFÉ', 'CIDREIRA',
#        'INHACORÁ', 'NÃO-ME-TOQUE', 'ARROIO DO PADRE', 'VILA FLORES',
#        'SÃO PEDRO DO BUTIÁ', 'SÃO MARCOS', 'FAXINALZINHO',
#        'BOA VISTA DO INCRA', 'MONTE ALEGRE DOS CAMPOS', 'AMETISTA DO SUL',
#        'SALDANHA MARINHO', 'AJURICABA', 'VICENTE DUTRA', 'CRISSIUMAL',
#        'TOROPI', 'SÃO JOSÉ DAS MISSÕES', 'QUINZE DE NOVEMBRO', 'COLORADO',
#        'NOVA BOA VISTA', 'ARROIO DO TIGRE', 'ALMIRANTE TAMANDARÉ DO SUL',
#        'IMIGRANTE', 'PARAÍ', 'BARÃO DO TRIUNFO', 'SÃO PEDRO DA SERRA',
#        'TUPANDI', 'BENJAMIN CONSTANT DO SUL', 'CASEIROS', 'MATO LEITÃO',
#        'VILA MARIA', 'BOA VISTA DO SUL', 'MARQUES DE SOUZA',
#        'PONTE PRETA', 'CORONEL PILAR', 'MARCELINO RAMOS',
#        'BOM RETIRO DO SUL', 'FELIZ', 'ALTO FELIZ', 'FLORIANO PEIXOTO',
#        'PORTO VERA CRUZ', 'CORONEL BARROS', 'PUTINGA', 'CRISTAL DO SUL',
#        'HUMAITÁ', 'ALTO ALEGRE', 'RONDA ALTA', 'PAVERAMA',
#        'CACIQUE DOBLE', 'ITATIBA DO SUL', 'ARROIO DO MEIO', 'CENTENÁRIO',
#        'ESTRELA', 'MAMPITUBA', 'DOM PEDRO DE ALCÂNTARA', 'PAROBÉ',
#        'IVOTI', 'CAPIVARI DO SUL', 'SÃO LEOPOLDO', 'MAQUINÉ',
#        'BARRA DO GUARITA', 'TUNAS', 'QUEVEDOS', 'SALVADOR DO SUL',
#        'PINTO BANDEIRA', 'ESTAÇÃO', 'JACUTINGA', 'HARMONIA',
#        'NICOLAU VERGUEIRO', 'SÃO JOSÉ DO NORTE', 'CAPITÃO',
#        'SANTA CRUZ DO SUL', 'SÃO DOMINGOS DO SUL', 'ESMERALDA',
#        'SANTA MARIA DO HERVAL', 'SAPUCAIA DO SUL', 'SÃO JORGE',
#        'BARROS CASSAL', 'WESTFALIA', 'GUABIJU', 'DERRUBADAS', 'CHARRUA',
#        'ROCA SALES', 'GRAMADO', 'CANOAS', 'NOVO HAMBURGO', 'SEGREDO',
#        'GRAMADO XAVIER', 'VIADUTOS', 'VANINI'], dtype=object)

# %% [markdown]
# Let's use a Title Case format, as these words will only show up in labels and tooltips.

# %%
def title_except_prepositions(name):
    lowercase_words = ['de', 'do', 'da', 'dos', 'das', 'e']
    words = name.split()
    # Capitalize words conditionaly
    capitalized_words = [word.capitalize() if word.lower() not in lowercase_words  else word.lower() for word in words]
    # Join the words back into a single string
    return " ".join(capitalized_words)

# %%
# Apply the function to the column
df_cut_refined.loc[:, 'Município'] = df_cut_refined['Município'].apply(title_except_prepositions)

# %%
df_cut_refined["Município"].unique()
# Out:
# array(['Barra do Quaraí', 'Uruguaiana', 'Cachoeira do Sul', 'Camaquã',
#        'Viamão', 'São Gabriel', 'Porto Alegre', 'Canela', 'Bagé',
#        'Rio Grande', 'Tapes', 'Rosário do Sul', 'Arroio Grande',
#        'Dom Pedrito', 'Cristal', 'São Lourenço do Sul', 'Jaguarão',
#        'Candiota', 'Aceguá', 'Encruzilhada do Sul', 'Itaqui',
#        'São Vicente do Sul', 'São Pedro do Sul', 'Turuçu', 'Santo Ângelo',
#        'Jóia', 'Entre-ijuís', 'Tupanciretã', 'Ijuí', 'Cruz Alta',
#        'Nova Ramada', 'Campo Novo', 'Bom Jesus', 'Pinhal da Serra',
#        'São José dos Ausentes', 'Quaraí', "Sant'ana do Livramento",
#        'Palmeira das Missões', 'Doutor Maurício Cardoso',
#        'Bento Gonçalves', 'Passo do Sobrado', 'São Francisco de Paula',
#        'Venâncio Aires', 'Ipê', 'Rio Pardo', 'Minas do Leão',
#        'Campestre da Serra', 'Nova Prata', 'Jaquirana', 'Santa Tereza',
#        'Agudo', 'São Jerônimo', 'Santiago', 'São Luiz Gonzaga',
#        'Campina das Missões', 'Rolador', 'Unistalda',
#        'São Francisco de Assis', 'São Paulo das Missões',
#        'Roque Gonzales', 'Bossoroca', 'Cacequi', 'Alegrete',
#        'Lavras do Sul', 'Nova Esperança do Sul', 'Cândido Godói', 'Mata',
#        'Jaguari', 'Mato Queimado', 'Maçambará', 'Dilermando de Aguiar',
#        'Santa Margarida do Sul', 'São Borja', 'Porto Lucena', 'São Sepé',
#        'Santa Maria', 'Júlio de Castilhos', 'Santo Cristo', 'Itacurubi',
#        'Santa Bárbara do Sul', 'Caçapava do Sul', 'Ibirubá', 'Barracão',
#        'Candelária', 'Capão do Leão', 'Pelotas', 'Salvador das Missões',
#        'Cambará do Sul', 'Erval Seco', 'Três de Maio', 'Tio Hugo',
#        'Formigueiro', 'Rio dos Índios', 'André da Rocha', 'Butiá',
#        'Barra do Ribeiro', 'Portão', 'Cachoeirinha', 'Sapiranga',
#        'Araricá', 'Mostardas', 'Gravataí', 'Glorinha', 'Taquara',
#        'Santo Antônio da Patrulha', 'Pirapó', 'Santo Antônio das Missões',
#        'Porto Xavier', 'Dezesseis de Novembro', 'Garruchos',
#        'Manoel Viana', 'São Nicolau', 'Pantano Grande', 'Novo Cabrais',
#        'Iraí', 'Rodeio Bonito', 'Estrela Velha', 'Fortaleza dos Valos',
#        'Ibarama', 'Pinheirinho do Vale', 'Condor', 'Vista Alegre',
#        'Pinheiro Machado', 'Frederico Westphalen', 'Restinga Seca',
#        'Paraíso do Sul', 'Alpestre', 'Cerro Grande', 'Pejuçara',
#        'São João do Polêsine', 'Dona Francisca', 'Herval', 'Seberi',
#        'Palmitinho', 'Caiçara', 'Dois Irmãos das Missões',
#        'Santa Vitória do Palmar', 'Boa Vista das Missões', 'Piratini',
#        'Santo Augusto', 'Sagrada Família', 'Jaboticaba', 'Novo Xingu',
#        'Novo Barreiro', 'Panambi', 'Pinhal', 'Chapada', 'Hulha Negra',
#        'Pinhal Grande', 'Boa Vista do Cadeado', 'Salto do Jacuí',
#        'Nova Palma', 'Tenente Portela', 'Lajeado do Bugre',
#        'Coronel Bicaco', 'Redentora', 'Senador Salgado Filho',
#        'Capão do Cipó', 'Tiradentes do Sul', 'Barra Funda',
#        'Liberato Salzano', 'Campos Borges', 'Sete de Setembro',
#        'São Miguel das Missões', 'Tucunduva', 'Nova Candelária',
#        'Selbach', 'Pedro Osório', 'Constantina', 'Santa Rosa',
#        'Cerro Branco', 'Giruá', 'Caibaté', 'Alegria', 'Augusto Pestana',
#        'Guarani das Missões', 'Porto Mauá', 'Ubiretama', 'Catuípe',
#        'Tuparendi', 'Independência', 'Horizontina', 'Chiapetta',
#        'Vila Nova do Sul', 'Pedras Altas', 'Jari', 'Passa Sete',
#        'Engenho Velho', 'Novo Machado', 'Boa Vista do Buricá',
#        'Carazinho', 'Rondinha', 'Jacuizinho', 'Nonoai', 'Cerrito',
#        'Canguçu', 'Trindade do Sul', 'Vitória das Missões', 'Sananduva',
#        'Teutônia', 'Triunfo', 'Entre Rios do Sul', 'Lagoão',
#        'Barão de Cotegipe', 'Progresso', 'São João da Urtiga',
#        'Maximiliano de Almeida', 'Guaporé', 'Arroio dos Ratos',
#        'Eldorado do Sul', 'Sertão', 'Garibaldi', 'Lagoa Vermelha',
#        'Pontão', 'Santo Antônio do Planalto', 'Marau', 'Erechim',
#        'Machadinho', 'David Canabarro', 'Veranópolis', 'Mato Castelhano',
#        'Aratiba', 'General Câmara', 'Nova Bassano', 'Antônio Prado',
#        'Mormaço', 'Três Arroios', 'Mariano Moro', 'Barão', 'Passo Fundo',
#        'Morro Redondo', 'São Valentim', 'Campinas do Sul',
#        'Carlos Barbosa', 'Vale Verde', 'Cerro Grande do Sul',
#        'Vista Alegre do Prata', 'Erval Grande', 'Áurea', 'Ibiraiaras',
#        'Sertão Santana', 'Pareci Novo', 'Santa Clara do Sul', 'Gentil',
#        'Sentinela do Sul', 'Boqueirão do Leão', 'Santo Antônio do Palma',
#        'Chuvisca', 'Guaíba', 'Bom Princípio', 'Água Santa',
#        'Quatro Irmãos', 'Charqueadas', 'Protásio Alves',
#        'Amaral Ferrador', 'Barra do Rio Azul', 'Soledade', 'Ibirapuitã',
#        'Tapejara', 'Santa Cecília do Sul', 'Ciríaco', 'São José do Ouro',
#        'Espumoso', 'Lagoa dos Três Cantos', 'Serafina Corrêa', 'Vacaria',
#        'Tavares', 'Caxias do Sul', 'Torres', 'Nova Hartz',
#        'Nova Roma do Sul', 'São Sebastião do Caí', 'Capela de Santana',
#        'Três Coroas', 'Nova Pádua', 'Flores da Cunha', 'Rolante',
#        'São José do Hortêncio', 'Muitos Capões', 'Nova Petrópolis',
#        'Palmares do Sul', 'Estância Velha', 'Riozinho', 'Caraá',
#        'Dois Irmãos', 'Alvorada', 'Osório', 'Terra de Areia', 'Itati',
#        'Xangri-lá', 'Getúlio Vargas', 'Planalto', 'Erebango', 'Casca',
#        'Eugênio de Castro', 'Paulo Bento', 'Fontoura Xavier', 'Alecrim',
#        'Cerro Largo', 'Dois Lajeados', 'Montenegro', 'Victor Graeff',
#        'Braga', 'Tapera', 'Santana da Boa Vista', 'Cotiporã',
#        'Farroupilha', 'Campo Bom', 'Taquaruçu do Sul',
#        'Faxinal do Soturno', 'Novo Tiradentes', 'Silveira Martins',
#        'São Pedro das Missões', 'Bozano', 'Itaara', 'Vista Gaúcha',
#        'Sobradinho', 'São Valério do Sul', 'Três Passos',
#        'Gramado dos Loureiros', 'Sarandi', 'São José do Inhacorá',
#        'Coqueiros do Sul', 'Coxilha', 'São Martinho da Serra',
#        'Fazenda Vilanova', 'Dom Feliciano', 'Paim Filho', 'Ibiaçá',
#        'Muliterno', 'Cruzaltense', 'São Valentim do Sul',
#        'Mariana Pimentel', 'Capão Bonito do Sul', 'Gaurama', 'Nova Araçá',
#        'Severiano de Almeida', 'Ernestina', 'Vila Lângaro',
#        'Monte Belo do Sul', 'Fagundes Varela', 'Cruzeiro do Sul',
#        'União da Serra', 'Arambaré', 'Três Palmeiras', 'Taquari',
#        'Capão da Canoa', 'Presidente Lucena', 'Picada Café', 'Cidreira',
#        'Inhacorá', 'Não-me-toque', 'Arroio do Padre', 'Vila Flores',
#        'São Pedro do Butiá', 'São Marcos', 'Faxinalzinho',
#        'Boa Vista do Incra', 'Monte Alegre dos Campos', 'Ametista do Sul',
#        'Saldanha Marinho', 'Ajuricaba', 'Vicente Dutra', 'Crissiumal',
#        'Toropi', 'São José das Missões', 'Quinze de Novembro', 'Colorado',
#        'Nova Boa Vista', 'Arroio do Tigre', 'Almirante Tamandaré do Sul',
#        'Imigrante', 'Paraí', 'Barão do Triunfo', 'São Pedro da Serra',
#        'Tupandi', 'Benjamin Constant do Sul', 'Caseiros', 'Mato Leitão',
#        'Vila Maria', 'Boa Vista do Sul', 'Marques de Souza',
#        'Ponte Preta', 'Coronel Pilar', 'Marcelino Ramos',
#        'Bom Retiro do Sul', 'Feliz', 'Alto Feliz', 'Floriano Peixoto',
#        'Porto Vera Cruz', 'Coronel Barros', 'Putinga', 'Cristal do Sul',
#        'Humaitá', 'Alto Alegre', 'Ronda Alta', 'Paverama',
#        'Cacique Doble', 'Itatiba do Sul', 'Arroio do Meio', 'Centenário',
#        'Estrela', 'Mampituba', 'Dom Pedro de Alcântara', 'Parobé',
#        'Ivoti', 'Capivari do Sul', 'São Leopoldo', 'Maquiné',
#        'Barra do Guarita', 'Tunas', 'Quevedos', 'Salvador do Sul',
#        'Pinto Bandeira', 'Estação', 'Jacutinga', 'Harmonia',
#        'Nicolau Vergueiro', 'São José do Norte', 'Capitão',
#        'Santa Cruz do Sul', 'São Domingos do Sul', 'Esmeralda',
#        'Santa Maria do Herval', 'Sapucaia do Sul', 'São Jorge',
#        'Barros Cassal', 'Westfalia', 'Guabiju', 'Derrubadas', 'Charrua',
#        'Roca Sales', 'Gramado', 'Canoas', 'Novo Hamburgo', 'Segredo',
#        'Gramado Xavier', 'Viadutos', 'Vanini'], dtype=object)

# %% [markdown]
# ### 3. `Categoria de Risco`

# %%
df_cut_refined["Categoria de Risco"].unique()
# Out:
# array(['Não Classificado', 'Médio', 'Baixo', 'Não se Aplica', 'Alto'],
#       dtype=object)

# %% [markdown]
# We can just apply an order, as it is a nominal, ordered variable.

# %%
risk_order = ["Baixo", "Médio", "Alto", "Não Classificado", "Não se Aplica"]
df_cut_refined.loc[:, "Categoria de Risco"] = pd.Categorical(df_cut_refined["Categoria de Risco"], categories=risk_order, ordered=True)

# %%
df_cut_refined["Categoria de Risco"].unique()
# Out:
# array(['Não Classificado', 'Médio', 'Baixo', 'Não se Aplica', 'Alto'],
#       dtype=object)

# %% [markdown]
# ### 4. `Dano Potencial Associado`

# %%
risk_order = ["Baixo", "Médio", "Alto", "Não Classificado"]

df_copy = df_cut_refined.copy()
df_copy["Dano Potencial Associado"] = pd.Categorical(
    df_copy["Dano Potencial Associado"],
    categories=risk_order,
    ordered=True
)

# %%
df_copy["Dano Potencial Associado"].unique()
# Out:
# ['Não Classificado', 'Alto', 'Médio', 'Baixo']
# Categories (4, object): ['Baixo' < 'Médio' < 'Alto' < 'Não Classificado']

# %% [markdown]
# ### 5. `Regulada pela PNSB`

# %%
df_copy["Regulada pela PNSB"].unique()
# Out:
# array(['Sim', 'Não Classificada', 'Não'], dtype=object)

# %% [markdown]
# ### 5. `Possui Plano de Segurança`

# %%
df_copy["Possui Plano de Segurança"].unique()
# Out:
# array(['Não', 'Sim'], dtype=object)

# %% [markdown]
# ### 6. `Possui Revisão Periódica`

# %%
df_copy["Possui Revisão Periódica"].unique()
# Out:
# array(['Não', 'Sim'], dtype=object)

# %% [markdown]
# ### 7. `Completude dos dados`

# %%
df_copy["Completude dos dados"].unique()
# Out:
# array(['média', 'boa', 'mínima', 'ótima', 'baixa'], dtype=object)

# %%
df_copy["Completude dos dados"] = df_copy["Completude dos dados"].str.title()


# df_cut_refined.loc[:, "Categoria de Risco"] = pd.Categorical(df_cut_refined["Categoria de Risco"], categories=risk_order, ordered=True)

# %%
data_completeness_order = df_copy["Completude dos dados"].unique()
data_completeness_order = ["Mínima", "Baixa", "Média", "Boa", "Ótima"]

df_copy.loc[:, "Completude dos dados"] = pd.Categorical(df_copy["Completude dos dados"], categories=data_completeness_order, ordered=True )

# %%
df_copy.head()
# Out:
#       Código SNISB                                   Nome da Barragem  UF  \
# 2415          5324                            Elias Scholsser Doviggi  RS
# 2465          5420        COOPERATIVA AGRICOLA MISTA SÃO MARCOS LTDA.  RS
# 2468          6421                   Instituto Rio Grandense do Arroz  RS
# 2682          6514  AUD - Associação dos Usuários do Perímetro de ...  RS
# 7729         17114  Associação dos Moradores do Assentamento Filho...  RS
#
#              Município  Latitude  Longitude Categoria de Risco  \
# 2415   Barra do Quaraí -30.21858  -57.48136   Não Classificado
# 2465        Uruguaiana -29.54631  -56.82289   Não Classificado
# 2468  Cachoeira do Sul -30.22500  -52.93972   Não Classificado
# 2682           Camaquã -30.82069  -51.84369              Médio
# 7729            Viamão -30.07369  -50.86181   Não Classificado
#
#      Dano Potencial Associado Regulada pela PNSB Possui Plano de Segurança  \
# 2415         Não Classificado                Sim                       Não
# 2465         Não Classificado                Sim                       Não
# 2468         Não Classificado                Sim                       Não
# 2682                     Alto                Sim                       Não
# 7729         Não Classificado                Sim                       Não
#
#      Possui Revisão Periódica Completude dos dados  Altura Fundação (m)  \
# 2415                      Não                Média                 8.19
# 2465                      Não                Média                 7.00
# 2468                      Não                Média                13.50
# 2682                      Não                  Boa                26.00
# 7729                      Não                Média                14.62
#
#       Capacidade (hm³)    Nome_Curso_dágua    Faixa de altura  \
# 2415             3.192  Arroio Quaraí Chico  7,5 m < h < 15 m
# 2465            60.965             SEM NOME         h < 7,5 m
# 2468            34.779   Arroio Capanezinho  7,5 m < h < 15 m
# 2682           170.000          Arroio Duro   15 m < h < 30 m
# 7729            12.973             SEM NOME  7,5 m < h < 15 m
#
#               Faixa de volume
# 2415  Pequena entre 3 e 5 hm³
# 2465                    Média
# 2468                    Média
# 2682                   Grande
# 7729                    Média

# %%
df_copy["Completude dos dados"].unique()
# Out:
# array(['Média', 'Boa', 'Mínima', 'Ótima', 'Baixa'], dtype=object)

# %% [markdown]
# ### 6. `Nome_Curso_dágua`

# %%
df_copy["Nome_Curso_dágua "].value_counts()
# Out:
# Nome_Curso_dágua
# SEM NOME                2347
# Rio Jacuí                220
# Rio Uruguai              147
# Arroio Araçá             106
# Lajeado Grande           104
#                         ...
# Arroio São José            1
# Lajeado dos Nasários       1
# Arroio Daltro Filho        1
# Arroio Vicente Rosa        1
# Arroio Xadrez              1
# Name: count, Length: 859, dtype: int64

# %%
df_copy["Nome_Curso_dágua "].replace("SEM NOME", "S/N", inplace=True)
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_1620\3843843717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy["Nome_Curso_dágua "].replace("SEM NOME", "S/N", inplace=True)

# %% [markdown]
# ### 7 . `Faixa de altura`

# %%
df_copy["Faixa de altura"].unique()
# Out:
# array(['7,5 m < h < 15 m', 'h < 7,5 m', '15 m < h < 30 m',
#        'Sem Informação', '30 m < h < 60 m', '60 m < h < 100'],
#       dtype=object)

# %%
# Define a mapping dictionary to rename the categories
faixa_mapping = {
    '7,5 m < h < 15 m': '7.5-15m',
    'h < 7,5 m': '<7.5m',
    '15 m < h < 30 m': '15-30m',
    '30 m < h < 60 m': '30-60m',
    '60 m < h < 100': '60-100m'
}

# Replace the values in the 'Faixa de altura' column using the mapping
df_copy['Faixa de altura'] = df_copy['Faixa de altura'].replace(faixa_mapping)

# %%
df_copy.sample(3)
# Out:
#        Código SNISB     Nome da Barragem  UF        Município  Latitude  \
# 19377          5493        *136000000000  RS       Uruguaiana -29.64806
# 13022          3000             956/2005  RS  Flores da Cunha -29.03778
# 21283         11583  # Lenoar Assi Adriz  RS             Jóia -28.80580
#
#        Longitude Categoria de Risco Dano Potencial Associado  \
# 19377  -56.50833   Não Classificado                     Alto
# 13022  -51.14333   Não Classificado         Não Classificado
# 21283  -54.23532   Não Classificado         Não Classificado
#
#       Regulada pela PNSB Possui Plano de Segurança Possui Revisão Periódica  \
# 19377                Sim                       Não                      Não
# 13022   Não Classificada                       Não                      Não
# 21283   Não Classificada                       Não                      Não
#
#       Completude dos dados  Altura Fundação (m)  Capacidade (hm³)  \
# 19377               Mínima                  NaN             0.714
# 13022               Mínima                  3.5             0.003
# 21283               Mínima                  NaN             0.001
#
#       Nome_Curso_dágua  Faixa de altura    Faixa de volume
# 19377               S/N  Sem Informação  Pequena até 1 hm³
# 13022               S/N           <7.5m  Pequena até 1 hm³
# 21283      Rio Piratini  Sem Informação  Pequena até 1 hm³

# %% [markdown]
# ### 8. `Faixa de volume`

# %%
df_copy["Faixa de volume"].unique()
# Out:
# array(['Pequena entre 3 e 5 hm³', 'Média', 'Grande', 'Pequena até 1 hm³',
#        'Pequena entre 1 e 3 hm³', 'Sem Informação', 'Muito Grande'],
#       dtype=object)

# %%
# Extracting Size and Volume Range by defining patterns
import re

# Function to extract size
def extract_size(value):
    size_mapping = {
        'Pequena': 'Pequena',
        'Média': 'Média',
        'Grande': 'Grande',
        'Muito Grande': 'Muito Grande'
    }
    for keyword, size in size_mapping.items():
        if keyword in value:
            return size
    return 'Sem Informação'

# Function to extract volume range
def extract_volume_range(value):
    match = re.search(r'\d+ hm³|\d+ e \d+ hm³', value)
    if match:
        return match.group()
    elif 'Sem Informação' in value:
        return 'Sem Informação'
    else:
        return ''

# Create two new columns using the above functions
df_copy['Faixa Volume'] = df_copy['Faixa de volume'].apply(extract_size)
df_copy['Volume Intervalo'] = df_copy['Faixa de volume'].apply(extract_volume_range)

# %%
df_copy = df_copy.reset_index(drop=True)

# %%
df_copy.sample(5)
# Out:
#       Código SNISB               Nome da Barragem  UF               Município  \
# 6646          6586               # Agostinho Pasa  RS           Caxias do Sul
# 1878         13300  # José Francisco Leal Machado  RS                São Sepé
# 2998          9800        # Irmo Elzário Sagrillo  RS  São Francisco de Assis
# 309           3378                      1488/2012  RS               Rio Pardo
# 6430         10242        # LIRIA SEIBERT BASTIAN  RS     Campina das Missões
#
#       Latitude  Longitude Categoria de Risco Dano Potencial Associado  \
# 6646 -29.17417  -51.29194   Não Classificado                    Médio
# 1878 -30.20426  -53.40016   Não Classificado         Não Classificado
# 2998 -29.25895  -55.27254   Não Classificado         Não Classificado
# 309  -30.10472  -52.61528   Não Classificado         Não Classificado
# 6430 -27.98572  -54.90714   Não Classificado         Não Classificado
#
#      Regulada pela PNSB Possui Plano de Segurança Possui Revisão Periódica  \
# 6646                Sim                       Não                      Não
# 1878   Não Classificada                       Não                      Não
# 2998   Não Classificada                       Não                      Não
# 309    Não Classificada                       Não                      Não
# 6430   Não Classificada                       Não                      Não
#
#      Completude dos dados  Altura Fundação (m)  Capacidade (hm³)  \
# 6646               Mínima                  NaN             0.001
# 1878               Mínima                  NaN             0.008
# 2998               Mínima                  NaN             0.051
# 309                Mínima                 5.56             0.311
# 6430               Mínima                  NaN             0.004
#
#          Nome_Curso_dágua  Faixa de altura    Faixa de volume Faixa Volume  \
# 6646                   S/N  Sem Informação  Pequena até 1 hm³      Pequena
# 1878  Arroio Santa Bárbara  Sem Informação  Pequena até 1 hm³      Pequena
# 2998               Rio Itu  Sem Informação  Pequena até 1 hm³      Pequena
# 309              Rio Jacuí           <7.5m  Pequena até 1 hm³      Pequena
# 6430          Rio Comandaí  Sem Informação  Pequena até 1 hm³      Pequena
#
#      Volume Intervalo
# 6646            1 hm³
# 1878            1 hm³
# 2998            1 hm³
# 309             1 hm³
# 6430            1 hm³

# %%
df_copy.drop(columns=["Faixa de volume"], inplace=True)

# %%
df_copy["Nome da Barragem"].unique()
# Out:
# array(['Elias Scholsser Doviggi',
#        'Cooperativa Agricola Mista São Marcos Ltda.',
#        'Instituto Rio Grandense Do Arroz', ...,
#        ' Barragem E009 – Fazenda Anonni',
#        'Barragem E013 – Fazenda Anonni', 'Barragem Cp Fepagro Viamão'],
#       dtype=object)

# %%
import re

# Function to clean and title case
def clean_and_title(name):
    # Ensure the input is a string
    name_str = str(name)
    # Check if it's numeric
    if name_str.isdigit():
        return name_str
    # Remove unwanted symbols like *, #, etc.
    cleaned_name = re.sub(r'[*#]', '', name_str)
    # Convert to title case
    return cleaned_name.title()

# Apply the function to the column after converting it to strings
df_copy['Nome da Barragem'] = df_copy['Nome da Barragem'].astype(str).apply(clean_and_title)

# Verify the changes
print(df_copy['Nome da Barragem'].head())
# Out:
# 0                              Elias Scholsser Doviggi
# 1          Cooperativa Agricola Mista São Marcos Ltda.
# 2                     Instituto Rio Grandense Do Arroz
# 3    Aud - Associação Dos Usuários Do Perímetro De ...
# 4    Associação Dos Moradores Do Assentamento Filho...
# Name: Nome da Barragem, dtype: object

# %%
df_copy.head()
# Out:
#    Código SNISB                                   Nome da Barragem  UF  \
# 0          5324                            Elias Scholsser Doviggi  RS
# 1          5420        Cooperativa Agricola Mista São Marcos Ltda.  RS
# 2          6421                   Instituto Rio Grandense Do Arroz  RS
# 3          6514  Aud - Associação Dos Usuários Do Perímetro De ...  RS
# 4         17114  Associação Dos Moradores Do Assentamento Filho...  RS
#
#           Município  Latitude  Longitude Categoria de Risco  \
# 0   Barra do Quaraí -30.21858  -57.48136   Não Classificado
# 1        Uruguaiana -29.54631  -56.82289   Não Classificado
# 2  Cachoeira do Sul -30.22500  -52.93972   Não Classificado
# 3           Camaquã -30.82069  -51.84369              Médio
# 4            Viamão -30.07369  -50.86181   Não Classificado
#
#   Dano Potencial Associado Regulada pela PNSB Possui Plano de Segurança  \
# 0         Não Classificado                Sim                       Não
# 1         Não Classificado                Sim                       Não
# 2         Não Classificado                Sim                       Não
# 3                     Alto                Sim                       Não
# 4         Não Classificado                Sim                       Não
#
#   Possui Revisão Periódica Completude dos dados  Altura Fundação (m)  \
# 0                      Não                Média                 8.19
# 1                      Não                Média                 7.00
# 2                      Não                Média                13.50
# 3                      Não                  Boa                26.00
# 4                      Não                Média                14.62
#
#    Capacidade (hm³)    Nome_Curso_dágua  Faixa de altura Faixa Volume  \
# 0             3.192  Arroio Quaraí Chico         7.5-15m      Pequena
# 1            60.965                  S/N           <7.5m        Média
# 2            34.779   Arroio Capanezinho         7.5-15m        Média
# 3           170.000          Arroio Duro          15-30m       Grande
# 4            12.973                  S/N         7.5-15m        Média
#
#   Volume Intervalo
# 0        3 e 5 hm³
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Export cleaning data.

# %%
import datetime

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# %%
df_copy.to_csv(f"{data_out}dam_data_clean_{timestamp}.csv", index=False, encoding="utf-8")
